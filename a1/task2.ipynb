# %% [markdown]
# # Task 2
#
# ## Similar to Task 1, but emphasize the utilization of method chaining and pipes

# %% [markdown]
# Imports:

# %%
import pandas as pd

# %% [markdown]
# ## 2.1 Load the dataset

# %% [markdown]
# Load the dataset:

# %%
df = pd.read_csv("JO0104D3_20250411-135149.csv", encoding="latin-1", na_values=['..'])
df.head(36)
# Out:
#                  region                                               crop  \
# 0   0114 Upplands Väsby                                  total arable land
# 1   0114 Upplands Väsby                                       winter wheat
# 2   0114 Upplands Väsby                                       spring wheat
# 3   0114 Upplands Väsby                                                rye
# 4   0114 Upplands Väsby                                      winter barley
# 5   0114 Upplands Väsby                                             barley
# 6   0114 Upplands Väsby                                      spring barley
# 7   0114 Upplands Väsby                                               oats
# 8   0114 Upplands Väsby                          mixed grain and triticale
# 9   0114 Upplands Väsby                      ley for hay and forage plants
# 10  0114 Upplands Väsby                                          triticale
# 11  0114 Upplands Väsby                                        mixed grain
# 12  0114 Upplands Väsby  field peas for cooking, fodder peas, vetches a...
# 13  0114 Upplands Väsby                                         green peas
# 14  0114 Upplands Väsby                                        white beans
# 15  0114 Upplands Väsby                                       green fodder
# 16  0114 Upplands Väsby                               utilized ley for hay
# 17  0114 Upplands Väsby                                   utilized pasture
# 18  0114 Upplands Väsby                   utilized ley for hay and pasture
# 19  0114 Upplands Väsby               not utilized ley for hay and pasture
# 20  0114 Upplands Väsby                                      ley for seeds
# 21  0114 Upplands Väsby                                     table potatoes
# 22  0114 Upplands Väsby                  potatoes for processing of starch
# 23  0114 Upplands Väsby                                        sugar beets
# 24  0114 Upplands Väsby                                        winter rape
# 25  0114 Upplands Väsby                                        spring rape
# 26  0114 Upplands Väsby                                 winter turnip rape
# 27  0114 Upplands Väsby                                 spring turnip rape
# 28  0114 Upplands Väsby                                           oil flax
# 29  0114 Upplands Väsby                                horticulture plants
# 30  0114 Upplands Väsby                                        other crops
# 31  0114 Upplands Väsby                                      energy forest
# 32  0114 Upplands Väsby                                        fallow land
# 33  0114 Upplands Väsby                         other untilled arable land
# 34  0114 Upplands Väsby                            unspecified arable land
# 35      0115 Vallentuna                                  total arable land
#
#       1981    1985    1989    1990    1991    1992    1993    1994    1995  \
# 0   1715.0  1652.0  1614.0  1478.0  1419.0  1311.0  1288.0  1434.0  1398.0
# 1     80.0    40.0   477.0   520.0   180.0   213.0   195.0   194.0   230.0
# 2    212.0   208.0     NaN     NaN     7.0     NaN     NaN     NaN    12.0
# 3      NaN     5.0    82.0    72.0    26.0     NaN     NaN     NaN     NaN
# 4      NaN     NaN     NaN     NaN     NaN     NaN     6.0     6.0     NaN
# 5    500.0   586.0   264.0   213.0   328.0   106.0     NaN     NaN     NaN
# 6      NaN     NaN     NaN     NaN     NaN     NaN   114.0   127.0   135.0
# 7    225.0   199.0   142.0   194.0   111.0    92.0    70.0   175.0    85.0
# 8      NaN     NaN     NaN     7.0     NaN     NaN     NaN     NaN     NaN
# 9      NaN     NaN     NaN     NaN     NaN     NaN   189.0   157.0   145.0
# 10     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# 27    38.0     NaN     NaN     NaN     NaN
# 28     4.0     NaN     NaN    20.0     NaN
# 29    12.0     NaN     NaN     NaN     NaN
# 30     5.0     3.0     NaN     NaN     NaN
# 31     NaN     NaN     NaN     NaN     NaN
# 32   211.0   150.0   190.0   171.0   208.0
# 33    49.0     NaN     6.0    23.0     NaN
# 34     NaN    38.0    36.0    23.0     NaN
# 35  8049.0  7768.0  7701.0  7718.0  7939.0

# %% [markdown]
# ## 2.2 Group by region and year to find top N crops per region per year, using pipes and lambda functions

# %% [markdown]
# We are curious as to which crops are the most produced for each region per year:

# %%
df_top_3 = df.copy()

# drop rows that are not really crops
df_top_3.query("crop != 'total arable land'", inplace=True)
df_top_3.query("crop != 'other untilled arable land'", inplace=True)
df_top_3.query("crop != 'unspecified arable land'", inplace=True)

year_cols = df_top_3.columns[2:]

N_CROPS = 3

top_crops_per_year_region = (
    df_top_3.pipe(lambda x: x.groupby(['region', 'crop'])[year_cols].sum())
       .pipe(lambda x: x.reset_index())
       .pipe(lambda x: x.melt(id_vars=['region', 'crop'], var_name='year', value_name='land'))
       .pipe(lambda x: x.sort_values(by=['region', 'year', 'land'], ascending=[True, True, False]))
       .pipe(lambda x: x.groupby(['region', 'year']).head(N_CROPS))
       .pipe(lambda x: x.reset_index())
       .pipe(lambda x: x.drop("index", axis=1))
)

top_crops_per_year_region.head(50)
# Out:
#                  region                              crop  year    land
# 0   0114 Upplands Väsby                            barley  1981   500.0
# 1   0114 Upplands Väsby  utilized ley for hay and pasture  1981   229.0
# 2   0114 Upplands Väsby                              oats  1981   225.0
# 3   0114 Upplands Väsby                            barley  1985   586.0
# 4   0114 Upplands Väsby                      spring wheat  1985   208.0
# 5   0114 Upplands Väsby  utilized ley for hay and pasture  1985   201.0
# 6   0114 Upplands Väsby                      winter wheat  1989   477.0
# 7   0114 Upplands Väsby  utilized ley for hay and pasture  1989   275.0
# 8   0114 Upplands Väsby                            barley  1989   264.0
# 9   0114 Upplands Väsby                      winter wheat  1990   520.0
# 10  0114 Upplands Väsby                            barley  1990   213.0
# 11  0114 Upplands Väsby  utilized ley for hay and pasture  1990   213.0
# 12  0114 Upplands Väsby                            barley  1991   328.0
# 13  0114 Upplands Väsby  utilized ley for hay and pasture  1991   217.0
# 14  0114 Upplands Väsby                      winter wheat  1991   180.0
# 15  0114 Upplands Väsby  utilized ley for hay and pasture  1992   361.0
# 16  0114 Upplands Väsby                      winter wheat  1992   213.0
# 17  0114 Upplands Väsby                            barley  1992   106.0
# 18  0114 Upplands Väsby                      winter wheat  1993   195.0
# 19  0114 Upplands Väsby     ley for hay and forage plants  1993   189.0
# 20  0114 Upplands Väsby                  utilized pasture  1993   172.0
# 21  0114 Upplands Väsby                      winter wheat  1994   194.0
# 22  0114 Upplands Väsby                              oats  1994   175.0
# 23  0114 Upplands Väsby                  utilized pasture  1994   162.0
# 24  0114 Upplands Väsby                       fallow land  1995   444.0
# 25  0114 Upplands Väsby                      winter wheat  1995   230.0
# 26  0114 Upplands Väsby     ley for hay and forage plants  1995   145.0
# 27  0114 Upplands Väsby                      winter wheat  1999   291.0
# 28  0114 Upplands Väsby  utilized ley for hay and pasture  1999   256.0
# 29  0114 Upplands Väsby                       fallow land  1999   211.0
# 30  0114 Upplands Väsby                      winter wheat  2001   393.0
# 31  0114 Upplands Väsby  utilized ley for hay and pasture  2001   297.0
# 32  0114 Upplands Väsby                     spring barley  2001   188.0
# 33  0114 Upplands Väsby                      winter wheat  2002   330.0
# 34  0114 Upplands Väsby  utilized ley for hay and pasture  2002   323.0
# 35  0114 Upplands Väsby                       fallow land  2002   190.0
# 36  0114 Upplands Väsby                      winter wheat  2003   433.0
# 37  0114 Upplands Väsby  utilized ley for hay and pasture  2003   256.0
# 38  0114 Upplands Väsby                       fallow land  2003   171.0
# 39  0114 Upplands Väsby                      winter wheat  2005   408.0
# 40  0114 Upplands Väsby  utilized ley for hay and pasture  2005   402.0
# 41  0114 Upplands Väsby                       fallow land  2005   208.0
# 42      0115 Vallentuna                            barley  1981  2270.0
# 43      0115 Vallentuna                              oats  1981  1967.0
# 44      0115 Vallentuna  utilized ley for hay and pasture  1981  1771.0
# 45      0115 Vallentuna                            barley  1985  2190.0
# 46      0115 Vallentuna                              oats  1985  2055.0
# 47      0115 Vallentuna  utilized ley for hay and pasture  1985  1556.0
# 48      0115 Vallentuna  utilized ley for hay and pasture  1989  1940.0
# 49      0115 Vallentuna                              oats  1989  1519.0

# %% [markdown]
# ## 2.3 Filling missing values using different methods

# %% [markdown]
# ### 2.3.1 Approach 1: Interpolation

# %%
df_approach_1 = df.copy()
df_approach_1[year_cols] = df_approach_1[year_cols].interpolate(method='linear', axis=1)

# %% [markdown]
# ### 2.3.2 Approach 2: Imputation with Mean

# %%
df_approach_2 = df.copy()
df_approach_2[year_cols] = df_approach_2[year_cols].fillna(df_approach_2[year_cols].mean())

# %% [markdown]
# ### 2.3.3 Approach 3: Fill with Zeroes

# %% [markdown]
# For this dataset, replacing NaN values with zeros is a realistic approach. The absence of a recorded value likely indicates that the crop measurement was truly zero rather than an error.

# %%
df_approach_3 = df.copy()
df_approach_3[year_cols] = df_approach_3[year_cols].fillna(0)

# %% [markdown]
# ## 2.4 Comparison summary after applying each method, using method chaining

# %%
comparison_summary = pd.concat([
    df.isnull().sum().rename('Way-Before').to_frame(),
    df_approach_1.isnull().sum().rename('Interpolation').to_frame(),
    df_approach_2.isnull().sum().rename('Mean Imputation').to_frame(),
    df_approach_3.isnull().sum().rename('Filling with Zeros').to_frame(),
], axis=1)

comparison_summary
