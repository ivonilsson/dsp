# %% [markdown]
# # Task 1
# salam aleikum habob

# %%
import pandas as pd

df = pd.read_csv("JO0104D3_20250411-135149.csv", encoding='ISO-8859-1')
df.replace("..", 0, inplace=True)
df
# Out:
#                     region                        crop  1981  1985  1989  \
# 0      0114 Upplands Väsby           total arable land  1715  1652  1614
# 1      0114 Upplands Väsby                winter wheat    80    40   477
# 2      0114 Upplands Väsby                spring wheat   212   208     0
# 3      0114 Upplands Väsby                         rye     0     5    82
# 4      0114 Upplands Väsby               winter barley     0     0     0
# ...                    ...                         ...   ...   ...   ...
# 10145          2584 Kiruna                 other crops     0     0    10
# 10146          2584 Kiruna               energy forest     0     0     0
# 10147          2584 Kiruna                 fallow land     3    18    22
# 10148          2584 Kiruna  other untilled arable land     0    13     6
# 10149          2584 Kiruna     unspecified arable land     0     0     0
#
#        1990  1991  1992  1993  1994  1995  1999  2001  2002  2003  2005
# ...
